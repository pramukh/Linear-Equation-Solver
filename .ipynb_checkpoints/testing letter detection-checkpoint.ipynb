# %%
import cv2 as cv
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
def disp_img(img):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    plt.show()

# %%
mpl.rcParams['figure.dpi']= 150

# %%
img = cv.imread('division_testing.jpg')

# %%
img.shape
# Out:
# (648, 1152, 3)

# %%
disp_img(img)

# %%
gray = cv.cvtColor(img.copy(), cv.COLOR_BGR2GRAY)
blurred = cv.GaussianBlur(gray, (5, 5), 10)
thresh = cv.adaptiveThreshold(blurred, 255, 0, 1, 115, 1)

disp_img(thresh)

# %%
kernel = np.ones((3,3),np.uint8)
dilation = cv.dilate(thresh,kernel,iterations = 1)

# %%
disp_img(dilation)

# %%
contours, hierarchy = cv.findContours(dilation, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours = sorted(contours, key=lambda ctr: cv.boundingRect(ctr)[0])
rects = [cv.boundingRect(ctr) for ctr in contours]

# %%
contours
# Out:
# [array([[[692, 273]],
#
#         [[691, 274]],
#
#         [[670, 274]],
#
#         [[669, 275]],
#
#         [[650, 275]],
#
#         [[649, 276]],
#
#         [[591, 276]],
#
#         [[589, 274]],
#
#         [[550, 274]],
#
#         [[549, 275]],
#
#         [[549, 282]],
#
#         [[581, 282]],
#
#         [[583, 284]],
#
#         [[655, 284]],
#
#         [[656, 283]],
#
#         [[676, 283]],
#
#         [[677, 282]],
#
#         [[699, 282]],
#
#         [[700, 281]],
#
#         [[709, 281]],
#
#         [[709, 273]]], dtype=int32), array([[[602, 203]],
#
#         [[602, 216]],
#
#         [[610, 216]],
#
#         [[611, 215]],
#
#         [[612, 215]],
#
#         [[612, 207]],
#
#         [[611, 206]],
#
#         [[611, 205]],
#
#         [[610, 204]],
#
#         [[610, 203]]], dtype=int32), array([[[620, 333]],
#
#         [[619, 334]],
#
#         [[619, 335]],
#
#         [[618, 336]],
#
#         [[616, 336]],
#
#         [[615, 337]],
#
#         [[609, 337]],
#
#         [[608, 338]],
#
#         [[606, 338]],
#
#         [[605, 339]],
#
#         [[605, 345]],
#
#         [[606, 346]],
#
#         [[621, 346]],
#
#         [[622, 347]],
#
#         [[622, 348]],
#
#         [[623, 349]],
#
#         [[640, 349]],
#
#         [[641, 348]],
#
#         [[644, 348]],
#
#         [[644, 347]],
#
#         [[645, 346]],
#
#         [[646, 346]],
#
#         [[646, 345]],
#
#         [[647, 344]],
#
#         [[650, 344]],
#
#         [[650, 337]],
#
#         [[649, 336]],
#
#         [[640, 336]],
#
#         [[639, 337]],
#
#         [[638, 337]],
#
#         [[637, 336]],
#
#         [[637, 334]],
#
#         [[636, 333]]], dtype=int32)]

# %%
rects
# Out:
# [(549, 273, 161, 12), (602, 203, 11, 14), (605, 333, 46, 17)]

# %%
for ctr in contours:
    x1 = ctr[0]
    x2 = ctr[0] + ctr[2]

# %%
ouput_img = img.copy()
extracted_digits = []
pad = 1
for (x, y, w, h) in rects:
    extracted_digits.append(dilation.copy()[y-pad: y + h+pad, x-pad: x + w+pad])
    rect = cv.rectangle(ouput_img, (x, y), (x + w, y + h), (0, 0, 255), 3)

# %%
disp_img(ouput_img)
